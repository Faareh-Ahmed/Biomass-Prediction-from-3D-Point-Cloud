# %% [markdown]
# <a href="https://colab.research.google.com/github/Faareh-Ahmed/Biomass-Prediction-from-3D-Point-Cloud/blob/main/pointcloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Base directory inside content/sample_data
base_dir = '/content/sample_data/TextFilesData/20190828'

# Create folders from Tony e-w_20190828_001 to Tony e-w_20190828_013
for i in range(1, 14):
    folder_name = f'Tonye-w_20190828_{str(i).zfill(3)}'
    folder_path = os.path.join(base_dir, folder_name)
    os.makedirs(folder_path, exist_ok=True)

print("Folders created successfully!")
# Out:
# Folders created successfully!

# %%
base_dir_2 = '/content/sample_data/TextFilesData/20191002'
# Create folders from Tony e-w_20191002_001 to Tony e-w_20191002_013
for i in range(1, 14):
    folder_name = f'Tonye-w_20191002_{str(i).zfill(3)}'
    folder_path = os.path.join(base_dir_2, folder_name)
    os.makedirs(folder_path, exist_ok=True)

print("Folders created successfully!")
# Out:
# Folders created successfully!

# %%
import os

# Base directory where the folders are located
base_dir = '/content/sample_data/TextFilesData/20190828'

# Iterate over all the subdirectories in the base directory
for folder_name in os.listdir(base_dir):
    # Check if the folder name contains the incorrect 'Tonye-w'
    if 'Tony-e-w' in folder_name:
        # Replace 'Tonye-w' with 'Tony-e-w' in the folder name
        corrected_folder_name = folder_name.replace('Tony-e-w', 'Tonye-w')

        # Construct the full paths for the old and new folder names
        old_folder_path = os.path.join(base_dir, folder_name)
        new_folder_path = os.path.join(base_dir, corrected_folder_name)

        # Rename the folder
        os.rename(old_folder_path, new_folder_path)
        print(f"Renamed: {old_folder_path} -> {new_folder_path}")

print("Folder renaming completed!")
# Out:
# Renamed: /content/sample_data/TextFilesData/20190828/Tony-e-w_20190828_007 -> /content/sample_data/TextFilesData/20190828/Tonye-w_20190828_007
# Renamed: /content/sample_data/TextFilesData/20190828/Tony-e-w_20190828_012 -> /content/sample_data/TextFilesData/20190828/Tonye-w_20190828_012
# Renamed: /content/sample_data/TextFilesData/20190828/Tony-e-w_20190828_002 -> /content/sample_data/TextFilesData/20190828/Tonye-w_20190828_002
# Renamed: /content/sample_data/TextFilesData/20190828/Tony-e-w_20190828_003 -> /content/sample_data/TextFilesData/20190828/Tonye-w_20190828_003
# Renamed: /content/sample_data/TextFilesData/20190828/Tony-e-w_20190828_005 -> /content/sample_data/TextFilesData/20190828/Tonye-w_20190828_005
# Renamed: /content/sample_data/TextFilesData/20190828/Tony-e-w_20190828_009 -> /content/sample_data/TextFilesData/20190828/Tonye-w_20190828_009
# ...

# %%
import os

# Base directory where the folders are located
base_dir = '/content/sample_data/TextFilesData/20191002'

# Iterate over all the subdirectories in the base directory
for folder_name in os.listdir(base_dir):
    # Check if the folder name contains the incorrect 'Tonye-w'
    if 'Tony-e-w' in folder_name:
        # Replace 'Tonye-w' with 'Tony-e-w' in the folder name
        corrected_folder_name = folder_name.replace('Tony-e-w', 'Tonye-w')

        # Construct the full paths for the old and new folder names
        old_folder_path = os.path.join(base_dir, folder_name)
        new_folder_path = os.path.join(base_dir, corrected_folder_name)

        # Rename the folder
        os.rename(old_folder_path, new_folder_path)
        print(f"Renamed: {old_folder_path} -> {new_folder_path}")

print("Folder renaming completed!")
# Out:
# Renamed: /content/sample_data/TextFilesData/20191002/Tony-e-w_20191002_007 -> /content/sample_data/TextFilesData/20191002/Tonye-w_20191002_007
# Renamed: /content/sample_data/TextFilesData/20191002/Tony-e-w_20191002_003 -> /content/sample_data/TextFilesData/20191002/Tonye-w_20191002_003
# Renamed: /content/sample_data/TextFilesData/20191002/Tony-e-w_20191002_006 -> /content/sample_data/TextFilesData/20191002/Tonye-w_20191002_006
# Renamed: /content/sample_data/TextFilesData/20191002/Tony-e-w_20191002_005 -> /content/sample_data/TextFilesData/20191002/Tonye-w_20191002_005
# Renamed: /content/sample_data/TextFilesData/20191002/Tony-e-w_20191002_010 -> /content/sample_data/TextFilesData/20191002/Tonye-w_20191002_010
# Renamed: /content/sample_data/TextFilesData/20191002/Tony-e-w_20191002_009 -> /content/sample_data/TextFilesData/20191002/Tonye-w_20191002_009
# ...

# %%
cd /content/sample_data/TextFilesData
# Out:
# /content/sample_data/TextFilesData

# %% [markdown]
# # Drive Mounting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Path to your folder
folder_path = '/content/drive/My Drive/TextFilesData'

# List files in the folder to verify access
print(os.listdir(folder_path))
# Out:
# ['20191002', '20190828', 'test_list.txt', 'train_list.txt', 'gcn_model_weights_0.001epoch50.pth', 'model2_weights.pth', 'model3_weights.pth', 'model4_weights.pth', 'pointNet_weights.pth', 'pointNet2_weights.pth', 'pointNet3_weights.pth', 'pointNet4_weights.pth']

# %%
import pandas as pd

# Path to the train_list.txt file
train_list_path = '/content/drive/My Drive/TextFilesData/train_list.txt'
test_list_path='/content/drive/My Drive/TextFilesData/test_list.txt'

# Read the file into a DataFrame
df = pd.read_csv(train_list_path, delim_whitespace=True, header=None)
df_test=pd.read_csv(test_list_path, delim_whitespace=True, header=None)

# Display the DataFrame
print(df)
# Out:
# <ipython-input-4-2410e3183b95>:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(train_list_path, delim_whitespace=True, header=None)
# <ipython-input-4-2410e3183b95>:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_test=pd.read_csv(test_list_path, delim_whitespace=True, header=None)
#                   0                               1        2   3   4  5
# 0    /20190828/Tony    e-w_20190828_001/1-5-1-b.pcd   380.60   3   1  3
# 1    /20190828/Tony    e-w_20190828_001/1-7-1-b.pcd   309.27   4   1  3
# 2    /20190828/Tony    e-w_20190828_001/1-9-1-b.pcd   303.53   5   1  3
# 3    /20190828/Tony   e-w_20190828_001/1-11-1-b.pcd   410.57   6   1  3
# 4    /20190828/Tony   e-w_20190828_001/1-13-1-b.pcd   204.15   7   1  3
# ...

# %%
df.head()
# Out:
#                 0                              1       2  3  4  5
# 0  /20190828/Tony   e-w_20190828_001/1-5-1-b.pcd  380.60  3  1  3
# 1  /20190828/Tony   e-w_20190828_001/1-7-1-b.pcd  309.27  4  1  3
# 2  /20190828/Tony   e-w_20190828_001/1-9-1-b.pcd  303.53  5  1  3
# 3  /20190828/Tony  e-w_20190828_001/1-11-1-b.pcd  410.57  6  1  3
# 4  /20190828/Tony  e-w_20190828_001/1-13-1-b.pcd  204.15  7  1  3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       204 non-null    object
#  1   1       204 non-null    object
#  2   2       204 non-null    float64
#  3   3       204 non-null    int64
#  4   4       204 non-null    int64
#  5   5       204 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.7+ KB

# %%
df[0]=df[0]+df[1]
df[0]
df_test[0]=df_test[0]+df_test[1]
df_test[0]
# Out:
# 0        /20190828/Tonye-w_20190828_001/1-1-1-b.pcd
# 1        /20190828/Tonye-w_20190828_001/1-3-1-b.pcd
# 2       /20190828/Tonye-w_20190828_001/1-15-1-b.pcd
# 3       /20190828/Tonye-w_20190828_001/1-16-1-b.pcd
# 4        /20190828/Tonye-w_20190828_002/2-1-1-b.pcd
#                            ...
# 97     /20191002/Tonye-w_20191002_012/12-16-1-b.pcd
# 98      /20191002/Tonye-w_20191002_013/13-1-1-b.pcd
# 99      /20191002/Tonye-w_20191002_013/13-3-1-b.pcd
# 100    /20191002/Tonye-w_20191002_013/13-15-1-b.pcd
# 101    /20191002/Tonye-w_20191002_013/13-16-1-b.pcd
# Name: 0, Length: 102, dtype: object

# %%
df[0] = df[0].str.replace('.pcd', '.txt')
df[0]
df_test[0] = df_test[0].str.replace('.pcd', '.txt')
df_test[0]
# Out:
# 0        /20190828/Tonye-w_20190828_001/1-1-1-b.txt
# 1        /20190828/Tonye-w_20190828_001/1-3-1-b.txt
# 2       /20190828/Tonye-w_20190828_001/1-15-1-b.txt
# 3       /20190828/Tonye-w_20190828_001/1-16-1-b.txt
# 4        /20190828/Tonye-w_20190828_002/2-1-1-b.txt
#                            ...
# 97     /20191002/Tonye-w_20191002_012/12-16-1-b.txt
# 98      /20191002/Tonye-w_20191002_013/13-1-1-b.txt
# 99      /20191002/Tonye-w_20191002_013/13-3-1-b.txt
# 100    /20191002/Tonye-w_20191002_013/13-15-1-b.txt
# 101    /20191002/Tonye-w_20191002_013/13-16-1-b.txt
# Name: 0, Length: 102, dtype: object

# %%
df = df.drop(columns=[1])
df_test=df_test.drop(columns=[1])

# %%
df.head()
# Out:
#                                              0       2  3  4  5
# 0   /20190828/Tonye-w_20190828_001/1-5-1-b.txt  380.60  3  1  3
# 1   /20190828/Tonye-w_20190828_001/1-7-1-b.txt  309.27  4  1  3
# 2   /20190828/Tonye-w_20190828_001/1-9-1-b.txt  303.53  5  1  3
# 3  /20190828/Tonye-w_20190828_001/1-11-1-b.txt  410.57  6  1  3
# 4  /20190828/Tonye-w_20190828_001/1-13-1-b.txt  204.15  7  1  3

# %%
df_test.head()
# Out:
#                                              0       2   3  4  5
# 0   /20190828/Tonye-w_20190828_001/1-1-1-b.txt  477.15   1  1  3
# 1   /20190828/Tonye-w_20190828_001/1-3-1-b.txt  374.05   2  1  3
# 2  /20190828/Tonye-w_20190828_001/1-15-1-b.txt  256.30   9  1  3
# 3  /20190828/Tonye-w_20190828_001/1-16-1-b.txt  256.22  10  1  3
# 4   /20190828/Tonye-w_20190828_002/2-1-1-b.txt  264.73   1  2  3

# %%
df.describe()
# Out:
#                  2          3           4           5
# count   204.000000  204.00000  204.000000  204.000000
# mean    653.014461    6.95098    7.039216    3.490196
# std     378.610387    3.00206    3.776833    0.501134
# min     149.780000    3.00000    1.000000    3.000000
# 25%     302.427500    4.00000    4.000000    3.000000
# 50%     470.330000    6.00000    7.000000    3.000000
# 75%    1036.250000    8.00000   10.000000    4.000000
# max    1341.800000   12.00000   13.000000    4.000000

# %%
pip install torch torchvision torchaudio torch-geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.3 MB/s eta 0:00:00
# ...

# %%
pip install numpy pandas matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df
# Out:
#                                                 0        2   3   4  5
# 0      /20190828/Tonye-w_20190828_001/1-5-1-b.txt   380.60   3   1  3
# 1      /20190828/Tonye-w_20190828_001/1-7-1-b.txt   309.27   4   1  3
# 2      /20190828/Tonye-w_20190828_001/1-9-1-b.txt   303.53   5   1  3
# 3     /20190828/Tonye-w_20190828_001/1-11-1-b.txt   410.57   6   1  3
# 4     /20190828/Tonye-w_20190828_001/1-13-1-b.txt   204.15   7   1  3
# ..                                            ...      ...  ..  .. ..
# 199  /20191002/Tonye-w_20191002_013/13-11-1-b.txt  1177.20   6  13  4
# 200  /20191002/Tonye-w_20191002_013/13-13-1-b.txt   941.60   7  13  4
# 201  /20191002/Tonye-w_20191002_013/13-14-1-b.txt   568.00   8  13  4
# 202  /20191002/Tonye-w_20191002_013/13-17-1-b.txt   853.00  11  13  4
# 203  /20191002/Tonye-w_20191002_013/13-18-1-b.txt   686.00  12  13  4
#
# [204 rows x 5 columns]

# %% [markdown]
# # Load Train data

# %% [markdown]
# # Representing data in a Dataframe

# %%
# Base directory
base_dir = '/content/drive/My Drive/TextFilesData'

# Example to read point cloud data
def load_point_cloud(file_path):
    # Load the point cloud data from the .txt file
    point_cloud = pd.read_csv(file_path, delimiter=' ', header=None)  # Adjust delimiter based on your file format
    return point_cloud.values  # Convert to NumPy array or leave as DataFrame based on your needs

# Create a DataFrame to store point clouds and biomass values
data = []

for _, row in df.iterrows():
    full_path = base_dir + row[0]  # Construct full file path
    point_cloud = load_point_cloud(full_path)  # Load point cloud data
    biomass_value = row[2]  # Assuming biomass value is in the second column

    data.append([full_path, point_cloud, biomass_value])  # Store all in a list

# Convert list to DataFrame
df_point_clouds = pd.DataFrame(data, columns=["file_path", "point_cloud", "biomass"])

# Now you can access them easily:
# df_point_clouds["point_cloud"][0] -> First point cloud
# df_point_clouds["biomass"].mean() -> Compute average biomass

# %%
df_point_clouds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   file_path    204 non-null    object
#  1   point_cloud  204 non-null    object
#  2   biomass      204 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 4.9+ KB

# %%
df_point_clouds
# Out:
#                                              file_path  \
# 0    /content/drive/My Drive/TextFilesData/20190828...
# 1    /content/drive/My Drive/TextFilesData/20190828...
# 2    /content/drive/My Drive/TextFilesData/20190828...
# 3    /content/drive/My Drive/TextFilesData/20190828...
# 4    /content/drive/My Drive/TextFilesData/20190828...
# ..                                                 ...
# 199  /content/drive/My Drive/TextFilesData/20191002...
# 200  /content/drive/My Drive/TextFilesData/20191002...
# 201  /content/drive/My Drive/TextFilesData/20191002...
# 202  /content/drive/My Drive/TextFilesData/20191002...
# 203  /content/drive/My Drive/TextFilesData/20191002...
#
#                                            point_cloud  biomass
# 0    [[//X, Y, Z, intensity], [38783, nan, nan, nan...   380.60
# 1    [[//X, Y, Z, intensity], [34718, nan, nan, nan...   309.27
# 2    [[//X, Y, Z, intensity], [38470, nan, nan, nan...   303.53
# ...

# %%
df_point_clouds["point_cloud"]
# Out:
# 0      [[//X, Y, Z, intensity], [38783, nan, nan, nan...
# 1      [[//X, Y, Z, intensity], [34718, nan, nan, nan...
# 2      [[//X, Y, Z, intensity], [38470, nan, nan, nan...
# 3      [[//X, Y, Z, intensity], [41856, nan, nan, nan...
# 4      [[//X, Y, Z, intensity], [31104, nan, nan, nan...
#                              ...
# 199    [[//X, Y, Z, intensity], [31225, nan, nan, nan...
# 200    [[//X, Y, Z, intensity], [28003, nan, nan, nan...
# 201    [[//X, Y, Z, intensity], [21746, nan, nan, nan...
# 202    [[//X, Y, Z, intensity], [28082, nan, nan, nan...
# 203    [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# Name: point_cloud, Length: 204, dtype: object

# %%
df_point_clouds["point_cloud"][0]
# Out:
# array([['//X', 'Y', 'Z', 'intensity'],
#        ['38783', nan, nan, nan],
#        ['-526.33221436', '68988.50781250', '260.73196411', '1.000000'],
#        ...,
#        ['495.58929443', '69981.78125000', '282.49514771', '1.000000'],
#        ['492.92358398', '69981.78125000', '319.02612305', '1.000000'],
#        ['506.10852051', '69981.78125000', '321.54791260', '1.000000']],
#       dtype=object)

# %%
df_point_clouds["biomass"]
# Out:
# 0       380.60
# 1       309.27
# 2       303.53
# 3       410.57
# 4       204.15
#         ...
# 199    1177.20
# 200     941.60
# 201     568.00
# 202     853.00
# 203     686.00
# Name: biomass, Length: 204, dtype: float64

# %% [markdown]
# # Load Test Data

# %% [markdown]
# # loading Test data as a DataFrame

# %%
# Base directory
base_dir = '/content/drive/My Drive/TextFilesData'

# Example to read point cloud data
def load_point_cloud_test(file_path):
    # Load the point cloud data from the .txt file
    test_point_cloud = pd.read_csv(file_path, delimiter=' ', header=None)  # Adjust delimiter based on your file format
    return test_point_cloud.values  # Convert to NumPy array or leave as DataFrame based on your needs

# Create a DataFrame to store point clouds and biomass values
test_data = []

for _, row in df_test.iterrows():
    full_path = base_dir + row[0]  # Construct full file path
    test_point_cloud = load_point_cloud_test(full_path)  # Load point cloud data
    test_biomass_value = row[2]  # Assuming biomass value is in the second column

    test_data.append([full_path, point_cloud, biomass_value])  # Store all in a list

# Convert list to DataFrame
df_test_point_clouds = pd.DataFrame(test_data, columns=["file_path", "point_cloud", "biomass"])

# %%
df_test_point_clouds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   file_path    102 non-null    object
#  1   point_cloud  102 non-null    object
#  2   biomass      102 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 2.5+ KB

# %%
df_test_point_clouds
# Out:
#                                              file_path  \
# 0    /content/drive/My Drive/TextFilesData/20190828...
# 1    /content/drive/My Drive/TextFilesData/20190828...
# 2    /content/drive/My Drive/TextFilesData/20190828...
# 3    /content/drive/My Drive/TextFilesData/20190828...
# 4    /content/drive/My Drive/TextFilesData/20190828...
# ..                                                 ...
# 97   /content/drive/My Drive/TextFilesData/20191002...
# 98   /content/drive/My Drive/TextFilesData/20191002...
# 99   /content/drive/My Drive/TextFilesData/20191002...
# 100  /content/drive/My Drive/TextFilesData/20191002...
# 101  /content/drive/My Drive/TextFilesData/20191002...
#
#                                            point_cloud  biomass
# 0    [[//X, Y, Z, intensity], [22084, nan, nan, nan...    686.0
# 1    [[//X, Y, Z, intensity], [22084, nan, nan, nan...    686.0
# 2    [[//X, Y, Z, intensity], [22084, nan, nan, nan...    686.0
# ...

# %%
df_test_point_clouds["point_cloud"]
# Out:
# 0      [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# 1      [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# 2      [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# 3      [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# 4      [[//X, Y, Z, intensity], [22084, nan, nan, nan...
#                              ...
# 97     [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# 98     [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# 99     [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# 100    [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# 101    [[//X, Y, Z, intensity], [22084, nan, nan, nan...
# Name: point_cloud, Length: 102, dtype: object

# %%
df_test_point_clouds["point_cloud"][0]
# Out:
# array([['//X', 'Y', 'Z', 'intensity'],
#        ['22084', nan, nan, nan],
#        ['-471.76809692', '150721.64062500', '324.43429565', '2.000000'],
#        ...,
#        ['535.82299805', '151217.17187500', '444.28994751', '1.000000'],
#        ['548.35931396', '151217.17187500', '414.67544556', '1.000000'],
#        ['592.99792480', '151217.17187500', '282.99578857', '1.000000']],
#       dtype=object)

# %% [markdown]
# # Data Pre-Processing

# %%
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset

# Preprocess point cloud: remove headers, handle NaNs, center, and scale
def preprocess_point_cloud(point_cloud):
    # Convert point cloud to numerical values, skipping header rows
    point_cloud = np.array(point_cloud[2:], dtype=np.float32)

    # Remove rows with NaN values
    point_cloud = point_cloud[~np.isnan(point_cloud).any(axis=1)]

    # Center the data
    X, Y, Z = point_cloud[:, 0], point_cloud[:, 1], point_cloud[:, 2]
    X_centered = X - np.mean(X)
    Y_centered = Y - np.mean(Y)
    Z_centered = Z - np.mean(Z)

    # Apply scaling
    X_scaled = X_centered / 15.0
    Y_scaled = Y_centered / 15.0
    Z_scaled = Z_centered / 20.0

    # Reconstruct the point cloud
    point_cloud[:, 0] = X_scaled
    point_cloud[:, 1] = Y_scaled
    point_cloud[:, 2] = Z_scaled

    return point_cloud

# Pad point clouds to a fixed size
def pad_point_cloud(point_cloud, max_points=1024):
    num_points = point_cloud.shape[0]
    if num_points < max_points:
        padding = max_points - num_points
        point_cloud = np.pad(point_cloud, ((0, padding), (0, 0)), mode='constant', constant_values=0)
    else:
        point_cloud = point_cloud[:max_points, :]
    return point_cloud

# Load and preprocess data
def load_data_with_padding(df, max_points=1024):
    point_clouds = []
    biomass_values = []

    for _, row in df.iterrows():
        point_cloud = preprocess_point_cloud(row['point_cloud'])
        point_cloud = pad_point_cloud(point_cloud, max_points)
        point_clouds.append(point_cloud)
        biomass_values.append(row['biomass'])

    return np.array(point_clouds), np.array(biomass_values)

# Load point clouds and biomass data
point_clouds, biomass_values = load_data_with_padding(df_point_clouds)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(point_clouds, biomass_values, test_size=0.2, random_state=42)

# Custom Dataset class
class BiomassDataset(Dataset):
    def __init__(self, point_clouds, biomass_values):
        self.point_clouds = point_clouds
        self.biomass_values = biomass_values

    def __len__(self):
        return len(self.point_clouds)

    def __getitem__(self, idx):
        return torch.tensor(self.point_clouds[idx][:, :3], dtype=torch.float32), torch.tensor(self.biomass_values[idx], dtype=torch.float32)

# DataLoader for training and testing
train_dataset = BiomassDataset(X_train, y_train)
test_dataset = BiomassDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# %% [markdown]
# # Self Attention based PointNet Regression

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class SelfAttention(nn.Module):
    def __init__(self, dim, heads=4):
        super(SelfAttention, self).__init__()
        self.heads = heads
        self.scale = (dim // heads) ** -0.5  # Scaling factor

        self.qkv = nn.Linear(dim, dim * 3, bias=False)  # Create Q, K, V
        self.proj = nn.Linear(dim, dim)  # Final projection

    def forward(self, x):
        B, N, C = x.shape  # Batch, Num_Points, Channels
        qkv = self.qkv(x).chunk(3, dim=-1)  # Split into Q, K, V

        # Reshape for multi-head attention
        q, k, v = [t.view(B, N, self.heads, C // self.heads).transpose(1, 2) for t in qkv]

        attn = (q @ k.transpose(-2, -1)) * self.scale  # Compute attention scores
        attn = attn.softmax(dim=-1)  # Normalize

        x = (attn @ v).transpose(1, 2).contiguous().view(B, N, C)  # Apply attention and reshape
        x = self.proj(x)  # Final projection

        return x

class PointNetRegressor(nn.Module):
    def __init__(self):
        super(PointNetRegressor, self).__init__()

        # Shared MLP layers (Feature Extractors)
        self.conv1 = nn.Conv1d(3, 64, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, 1)
        self.bn2 = nn.BatchNorm1d(128)
        self.conv3 = nn.Conv1d(128, 256, 1)
        self.bn3 = nn.BatchNorm1d(256)

        # Self-Attention Layer (After feature extraction)
        self.self_attention = SelfAttention(dim=256, heads=4)

        # Global feature extraction
        self.fc1 = nn.Linear(256, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 1)

        # Dropout layer
        self.dropout = nn.Dropout(0.3)

        # Weight initialization
        self.apply(self.initialize_weights)

    def initialize_weights(self, m):
        if isinstance(m, nn.Conv1d) or isinstance(m, nn.Linear):
            nn.init.xavier_normal_(m.weight)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = x.transpose(1, 2)  # Change to (B, Channels, Points)

        # Feature Extraction (Convolutions + GELU)
        x = F.gelu(self.bn1(self.conv1(x)))
        x = F.gelu(self.bn2(self.conv2(x)))
        x = F.gelu(self.bn3(self.conv3(x)))

        x = x.transpose(1, 2)  # (B, Points, Features) for Attention

        # Apply Self-Attention
        x = self.self_attention(x)

        # Global Average Pooling
        x = torch.mean(x, 1)  # Average over all points

        # Fully Connected Layers
        x = F.gelu(self.fc1(x))
        x = self.dropout(x)
        x = F.gelu(self.fc2(x))
        x = self.fc3(x)  # Output regression value

        return x

# Initialize the model
model = PointNetRegressor()

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-3)  # L2 Regularization

# Learning rate scheduler
# Replace StepLR with ReduceLROnPlateau
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',         # Reduce LR when validation loss stops decreasing
    factor=0.7,         # Reduce LR by 30%
    patience=5,         # Wait 3 epochs with no improvement before reducing LR
)

# %% [markdown]
# # Hybrid Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# ==================== Data Preprocessing ====================
def preprocess_point_cloud(point_cloud):
    point_cloud = np.array(point_cloud[2:], dtype=np.float32)
    point_cloud = point_cloud[~np.isnan(point_cloud).any(axis=1)]
    X, Y, Z = point_cloud[:, 0], point_cloud[:, 1], point_cloud[:, 2]
    X_centered = X - np.mean(X)
    Y_centered = Y - np.mean(Y)
    Z_centered = Z - np.mean(Z)
    X_scaled = X_centered / 15.0
    Y_scaled = Y_centered / 15.0
    Z_scaled = Z_centered / 20.0
    point_cloud[:, 0] = X_scaled
    point_cloud[:, 1] = Y_scaled
    point_cloud[:, 2] = Z_scaled
    return point_cloud

def pad_point_cloud(point_cloud, max_points=1024):
    num_points = point_cloud.shape[0]
    if num_points < max_points:
        padding = max_points - num_points
        point_cloud = np.pad(point_cloud, ((0, padding), (0, 0)), mode='constant', constant_values=0)
    else:
        point_cloud = point_cloud[:max_points, :]
    return point_cloud

def load_data_with_padding(df, max_points=1024):
    point_clouds = []
    biomass_values = []
    for _, row in df.iterrows():
        point_cloud = preprocess_point_cloud(row['point_cloud'])
        point_cloud = pad_point_cloud(point_cloud, max_points)
        point_clouds.append(point_cloud)
        biomass_values.append(row['biomass'])
    return np.array(point_clouds), np.array(biomass_values)

# ==================== Data Augmentation ====================
def augment_point_cloud(pc):
    # Random rotation
    angle = np.random.uniform(-np.pi, np.pi)
    rot_mat = np.array([[np.cos(angle), -np.sin(angle), 0],
                        [np.sin(angle), np.cos(angle), 0],
                        [0, 0, 1]])
    pc[:, :3] = pc[:, :3] @ rot_mat

    # Random scaling
    scale = np.random.uniform(0.9, 1.1)
    pc[:, :3] *= scale

    # Gaussian noise
    noise = np.random.normal(0, 0.01, pc[:, :3].shape)
    pc[:, :3] += noise
    return pc

class BiomassDataset(Dataset):
    def __init__(self, point_clouds, biomass_values, training=False):
        self.point_clouds = point_clouds
        self.biomass_values = biomass_values
        self.training = training

    def __len__(self):
        return len(self.point_clouds)

    def __getitem__(self, idx):
        pc = self.point_clouds[idx]
        if self.training:  # Apply augmentations only during training
            pc = augment_point_cloud(pc)
        return torch.tensor(pc[:, :3], dtype=torch.float32), torch.tensor(self.biomass_values[idx], dtype=torch.float32)

# ==================== Model Architecture ====================
class SelfAttention(nn.Module):
    def __init__(self, dim, heads=4):
        super().__init__()
        self.heads = heads
        self.scale = (dim // heads) ** -0.5
        self.qkv = nn.Linear(dim, dim * 3, bias=False)
        self.proj = nn.Linear(dim, dim)

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x).chunk(3, dim=-1)
        q, k, v = [t.view(B, N, self.heads, C // self.heads).transpose(1, 2) for t in qkv]
        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        x = (attn @ v).transpose(1, 2).contiguous().view(B, N, C)
        return self.proj(x)

class PointNetPlusPlusBlock(nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.Conv2d(in_dim, out_dim, 1),
            nn.BatchNorm2d(out_dim),
            nn.GELU(),
            nn.Conv2d(out_dim, out_dim, 1),
            nn.BatchNorm2d(out_dim),
            nn.GELU()
        )

    def forward(self, x):
        return self.mlp(x)

class HybridModel(nn.Module):
    def __init__(self):
        super().__init__()
        # PointNet Feature Extractor
        self.conv1 = nn.Conv1d(3, 64, 1)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, 1)
        self.bn2 = nn.BatchNorm1d(128)
        self.conv3 = nn.Conv1d(128, 256, 1)
        self.bn3 = nn.BatchNorm1d(256)

        # Transformer Encoder
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=256, nhead=4),
            num_layers=3
        )

        # Prediction Head
        self.head = nn.Sequential(
            nn.Linear(256, 128),
            nn.SiLU(),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        x = x.transpose(1, 2)
        x = F.gelu(self.bn1(self.conv1(x)))
        x = F.gelu(self.bn2(self.conv2(x)))
        x = F.gelu(self.bn3(self.conv3(x)))
        x = x.transpose(1, 2)

        # Transformer
        x = self.transformer(x)
        x = torch.mean(x, dim=1)

        # Prediction
        return self.head(x)

# ==================== Loss Function ====================
class HuberLoss(nn.Module):
    def __init__(self, delta=1.0):
        super().__init__()
        self.delta = delta

    def forward(self, y_pred, y_true):
        error = y_true - y_pred
        abs_error = torch.abs(error)
        quadratic = torch.clamp(abs_error, max=self.delta)
        linear = abs_error - quadratic
        loss = 0.5 * quadratic**2 + self.delta * linear
        return loss.mean()  # Reduce to a scalar

# ==================== Training Setup ====================
def train(model, train_loader, optimizer, loss_fn):
    model.train()
    total_loss = 0
    for batch in train_loader:
        point_clouds, biomass = batch
        optimizer.zero_grad()
        outputs = model(point_clouds).squeeze()  # Squeeze to remove extra dimensions
        loss = loss_fn(outputs, biomass)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

def validate(model, val_loader, loss_fn):
    model.eval()
    total_loss = 0.0
    with torch.no_grad():
        for point_clouds, biomass in val_loader:
            outputs = model(point_clouds).squeeze()
            loss = loss_fn(outputs, biomass)
            total_loss += loss.item()
    return total_loss / len(val_loader)

def evaluate_model(model, val_loader):
    model.eval()
    predictions, biomass_values = [], []
    with torch.no_grad():
        for data in val_loader:
            point_clouds, biomass = data
            outputs = model(point_clouds)
            # Ensure predictions are always wrapped as a list (even for scalar outputs)
            pred = np.atleast_1d(outputs.squeeze().cpu().numpy()).tolist()
            predictions.extend(pred)
            biomass_values.extend(biomass.cpu().numpy().tolist())

    predictions = np.array(predictions)
    biomass_values = np.array(biomass_values)
    mse = mean_squared_error(biomass_values, predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(biomass_values, predictions)
    r2 = r2_score(biomass_values, predictions)
    print(f'Final Evaluation Metrics:\nMSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}')

# ==================== Main ====================
# Assume df_point_clouds is defined and loaded properly
point_clouds, biomass_values = load_data_with_padding(df_point_clouds)
X_train, X_test, y_train, y_test = train_test_split(point_clouds, biomass_values, test_size=0.2, random_state=42)

# Create datasets and dataloaders
train_dataset = BiomassDataset(X_train, y_train, training=True)
test_dataset = BiomassDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# Initialize model, optimizer, and loss modules
# Initialize model, optimizer, and loss modules
model = HybridModel()
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.05)
criterion = nn.ModuleDict({
    'mse': nn.MSELoss(),
    'huber': HuberLoss()
})

# Define the combined loss function for reuse (after criterion is defined)
def combined_loss(y_pred, y_true):
    return 0.7 * criterion['mse'](y_pred, y_true) + 0.3 * criterion['huber'](y_pred, y_true)
loss_fn = combined_loss

# Create a learning rate scheduler that monitors the validation loss
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.7,
    patience=3,
    verbose=True
)

# Training loop with both training and validation loss printing
num_epochs = 50
for epoch in range(num_epochs):
    train_loss = train(model, train_loader, optimizer, loss_fn)
    val_loss = validate(model, test_loader, loss_fn)

    # Step the scheduler based on the validation loss
    scheduler.step(val_loss)

    current_lr = optimizer.param_groups[0]['lr']
    print(f'Epoch {epoch+1:02d}: Train Loss = {train_loss:.4f}, Validation Loss = {val_loss:.4f}, lr = {current_lr}')

# Final evaluation results after training is complete
evaluate_model(model, test_loader)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 01: Train Loss = 394198.7548, Validation Loss = 302242.5156, lr = 0.001
# Epoch 02: Train Loss = 385281.8780, Validation Loss = 273904.2174, lr = 0.001
# ...

# %% [markdown]
# # BIONET Architecture

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


class CompletionModule(nn.Module):
    def __init__(self, input_dim=3, hidden_dim=1024, output_dim=3):
        super(CompletionModule, self).__init__()
        self.hidden_dim = hidden_dim  # Store hidden_dim as an attribute
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.ReLU(),
            nn.Linear(512, hidden_dim),
            nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, 512),
            nn.ReLU(),
            nn.Linear(512, output_dim)
        )

    def forward(self, x):
        batch_size, num_points, _ = x.shape
        x_flat = x.view(batch_size * num_points, -1)  # Flatten to (batch_size * num_points, input_dim)
        encoded_features = self.encoder(x_flat)  # (batch_size * num_points, hidden_dim)
        completed_points_flat = self.decoder(encoded_features)  # (batch_size * num_points, output_dim)
        completed_points = completed_points_flat.view(batch_size, num_points, -1)  # Reshape to (batch_size, num_points, output_dim)
        encoded_features = encoded_features.view(batch_size, num_points, self.hidden_dim)  # Reshape to (batch_size, num_points, hidden_dim)
        return completed_points, encoded_features

# %%
class RegularizationModule(nn.Module):
    def __init__(self, feature_dim=1024):
        super(RegularizationModule, self).__init__()
        self.mlp_query = nn.Sequential(
            nn.Linear(feature_dim, feature_dim),
            nn.ReLU()
        )
        self.mlp_key = nn.Sequential(
            nn.Linear(feature_dim, feature_dim),
            nn.ReLU()
        )
        self.mlp_value = nn.Sequential(
            nn.Linear(feature_dim, feature_dim),
            nn.ReLU()
        )

    def forward(self, reference_features, plot_features):
        # reference_features: (batch_size, feature_dim)
        # plot_features: (batch_size, num_points, feature_dim)
        query = self.mlp_query(reference_features)
        key = self.mlp_key(plot_features)
        value = self.mlp_value(plot_features)
        attention_scores = torch.matmul(query.unsqueeze(1), key.transpose(1, 2))
        attention_scores = F.softmax(attention_scores, dim=-1)
        regularized_features = torch.matmul(attention_scores, value).squeeze(1)
        return regularized_features

# %%
class ProjectionModule(nn.Module):
    def __init__(self, input_dim=3, hidden_dim=1024, grid_size=32):
        super(ProjectionModule, self).__init__()
        self.grid_size = grid_size
        self.cnn = nn.Sequential(
            nn.Conv2d(2, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Flatten(),
            nn.Linear(64 * (grid_size//4) * (grid_size//4), hidden_dim),
            nn.ReLU()
        )

    def forward(self, x):
        x_2d = x[:, :, :2]
        batch_size = x_2d.size(0)
        x_2d = x_2d.view(batch_size, self.grid_size, self.grid_size, 2)
        x_2d = x_2d.permute(0, 3, 1, 2)
        features = self.cnn(x_2d)
        return features

# %%
class FusionBlock(nn.Module):
    def __init__(self, feature_dim=1024):
        super(FusionBlock, self).__init__()
        self.mlp = nn.Sequential(
            nn.Linear(feature_dim * 3, feature_dim),
            nn.ReLU(),
            nn.Linear(feature_dim, 3)  # Output 3 weights
        )

    def forward(self, v_c, v_r, v_p):
        combined = torch.cat([v_c, v_r, v_p], dim=1)
        weights = F.softmax(self.mlp(combined), dim=1)
        fused = weights[:, 0:1] * v_c + weights[:, 1:2] * v_r + weights[:, 2:3] * v_p
        return fused

# %%
class BioNet(nn.Module):
    def __init__(self, input_dim=3, hidden_dim=1024, grid_size=32):
        super(BioNet, self).__init__()
        self.completion_module = CompletionModule(input_dim, hidden_dim)
        self.regularization_module = RegularizationModule(hidden_dim)
        self.projection_module = ProjectionModule(input_dim, hidden_dim, grid_size)
        self.fusion_block = FusionBlock(hidden_dim)
        self.final_mlp = nn.Sequential(
            nn.Linear(hidden_dim, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )

    def forward(self, x):
        completed_points, encoded_features = self.completion_module(x)
        reference_features = encoded_features.mean(dim=1)  # Global feature
        v_c = reference_features
        v_r = self.regularization_module(reference_features, encoded_features)
        v_p = self.projection_module(completed_points)
        fused_features = self.fusion_block(v_c, v_r, v_p)
        biomass_prediction = self.final_mlp(fused_features)
        return biomass_prediction

# %%
# Initialize the model, optimizer, and loss function
model = BioNet()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.SmoothL1Loss()  # As mentioned in the paper

# Dynamic Learning Rate Scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',       # Reduce LR when validation loss stops decreasing
    factor=0.8,       # Reduce the learning rate by a factor of 0.5
    patience=5,       # Wait 5 epochs before reducing LR after no improvement
)

# Training function
def train(model, train_loader, optimizer, criterion, device):
    model.train()
    total_loss = 0.0
    for batch_idx, (point_clouds, biomass_values) in enumerate(train_loader):
        point_clouds, biomass_values = point_clouds.to(device), biomass_values.to(device)

        # Forward pass
        optimizer.zero_grad()
        predicted_biomass = model(point_clouds)
        loss = criterion(predicted_biomass, biomass_values.unsqueeze(1))  # Add a dimension to match predictions

        # Backward pass
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(train_loader)

# Evaluation function
def evaluate(model, test_loader, criterion, device):
    model.eval()
    total_loss = 0.0
    with torch.no_grad():
        for batch_idx, (point_clouds, biomass_values) in enumerate(test_loader):
            point_clouds, biomass_values = point_clouds.to(device), biomass_values.to(device)

            # Forward pass
            predicted_biomass = model(point_clouds)
            loss = criterion(predicted_biomass, biomass_values.unsqueeze(1))

            total_loss += loss.item()

    return total_loss / len(test_loader)

# Training loop
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

num_epochs = 50
for epoch in range(num_epochs):
    train_loss = train(model, train_loader, optimizer, criterion, device)
    test_loss = evaluate(model, test_loader, criterion, device)
    # Adjust the learning rate based on validation loss
    scheduler.step(test_loss)

    # Print the current learning rate
    current_lr = optimizer.param_groups[0]['lr']
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, LR: {current_lr:.6f}")
# Out:
# Epoch [1/50], Train Loss: 644.0560, Test Loss: 514.4491, LR: 0.000100
# Epoch [2/50], Train Loss: 445.7046, Test Loss: 316.3810, LR: 0.000100
# Epoch [3/50], Train Loss: 369.4439, Test Loss: 286.5455, LR: 0.000100
# Epoch [4/50], Train Loss: 330.9870, Test Loss: 270.1677, LR: 0.000100
# Epoch [5/50], Train Loss: 316.5904, Test Loss: 235.9579, LR: 0.000100
# Epoch [6/50], Train Loss: 299.0812, Test Loss: 213.9885, LR: 0.000100
# Epoch [7/50], Train Loss: 277.6001, Test Loss: 214.7624, LR: 0.000100
# Epoch [8/50], Train Loss: 264.2044, Test Loss: 197.2550, LR: 0.000100
# Epoch [9/50], Train Loss: 257.1444, Test Loss: 175.2597, LR: 0.000100
# Epoch [10/50], Train Loss: 257.2623, Test Loss: 197.3419, LR: 0.000100
# Epoch [11/50], Train Loss: 270.1235, Test Loss: 195.1918, LR: 0.000100
# Epoch [12/50], Train Loss: 258.0404, Test Loss: 168.0949, LR: 0.000100
# Epoch [13/50], Train Loss: 230.2945, Test Loss: 153.4444, LR: 0.000100
# ...

# %%
# Save the model to Google Drive
model_save_path = '/content/drive/My Drive/BIONET3.pth'
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /content/drive/My Drive/BIONET3.pth

# %%
model_load_path = '/content/drive/My Drive/BIONET3.pth'
model.load_state_dict(torch.load(model_load_path))
model.eval()

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Evaluation function
def evaluate(model, test_loader, criterion, device):
    model.eval()
    total_loss = 0.0
    all_predictions = []
    all_targets = []
    with torch.no_grad():
        for batch_idx, (point_clouds, biomass_values) in enumerate(test_loader):
            point_clouds, biomass_values = point_clouds.to(device), biomass_values.to(device)
            predicted_biomass = model(point_clouds)
            loss = criterion(predicted_biomass, biomass_values.unsqueeze(1))
            total_loss += loss.item()

            all_predictions.append(predicted_biomass.cpu().numpy())
            all_targets.append(biomass_values.cpu().numpy())

    all_predictions = np.concatenate(all_predictions)
    all_targets = np.concatenate(all_targets)

    mse = mean_squared_error(all_targets, all_predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(all_targets, all_predictions)
    r2 = r2_score(all_targets, all_predictions)

    print(f"MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R2: {r2:.4f}")

    return total_loss / len(test_loader)

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Evaluation (Assuming test_loader and criterion are already defined)
evaluate(model, test_loader, criterion, device)
# Out:
# <ipython-input-24-d938ee5984a0>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_load_path))
# ...

# %% [markdown]
# # PointNet

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

# Define the PointNet-based regression model
class PointNetRegression(nn.Module):
    def __init__(self, input_dim=4, output_dim=1):
        super(PointNetRegression, self).__init__()



        # Input layer for point features (e.g., XYZ coordinates, intensity)
        self.fc1 = nn.Linear(input_dim, 64)
        self.bn1 = nn.BatchNorm1d(64)

        # Hidden layers
        self.fc2 = nn.Linear(64, 128)
        self.bn2 = nn.BatchNorm1d(128)

        self.fc3 = nn.Linear(128, 1024)
        self.bn3 = nn.BatchNorm1d(1024)

        # Global pooling layer (global sum pooling for regression)
        self.global_pool = nn.Identity()

        # Fully connected layers for the regression output
        self.fc4 = nn.Linear(1024, 512)
        self.bn4 = nn.BatchNorm1d(512)

        self.fc5 = nn.Linear(512, 256)
        self.bn5 = nn.BatchNorm1d(256)

        self.fc6 = nn.Linear(256, output_dim)  # Output AGB/wood volume

        # Activation function: GELU
        self.gelu = nn.GELU()

    def forward(self, x, mask=None):

        # print(f"Shape before applying mask: {x.shape}")  # Print the shape before masking

        # Input x has shape (batch_size, num_points, input_dim)
        batch_size, num_points, input_dim = x.size()

         # Apply MLP to each point individually (point-wise feature extraction)
        x = self.fc1(x)  # Shape: (batch_size, num_points, 64)
        x = self.gelu(self.bn1(x.transpose(1, 2)))  # Permute to (batch_size, 64, num_points) for batch norm
        x = self.fc2(x.transpose(1, 2))  # Transpose back to (batch_size, num_points, 128)
        x = self.gelu(self.bn2(x.transpose(1, 2)))  # Batch norm applied to (batch_size, 128, num_points)

        x = self.fc3(x.transpose(1, 2))  # Continue with the same process
        x = self.gelu(self.bn3(x.transpose(1, 2)))

        # print(f"Shape of x before applying mask: {x.shape}")  # Print the shape before masking
        # print(f"Shape of mask before applying mask: {mask.shape}")  # Print the shape before masking


        # Apply mask to ignore padded points (if provided)
        if mask is not None:
            mask = mask.unsqueeze(1)  # Shape: (batch_size, 1, num_points)
            x = x * mask  # Shape: (batch_size, num_points, 1024)

        # Global sum pooling: sum all point features for each sample in the batch
        x = torch.sum(x, dim=2)  # Shape: (batch_size, 1024)

        # Fully connected layers for regression
        x = self.gelu(self.bn4(self.fc4(x)))
        x = self.gelu(self.bn5(self.fc5(x)))
        x = self.fc6(x)  # Output is the regression value

        return x

# %%
# Preprocess point clouds: remove headers and handle NaNs
# Preprocess point clouds: remove headers, center the data, and apply scaling
def preprocess_point_clouds_with_centering(point_clouds):
    processed_point_clouds = []

    for pc in point_clouds:
        # Remove the header (first two rows)
        pc_cleaned = pc[2:]  # Skip the first row (['//X', 'Y', 'Z', 'intensity'])

        # Convert data to float and replace NaNs with 0
        pc_cleaned = pc_cleaned.astype(np.float32)

        # Extract the X, Y, Z, and intensity columns
        X = pc_cleaned[:, 0]
        Y = pc_cleaned[:, 1]
        Z = pc_cleaned[:, 2]
        intensity = pc_cleaned[:, 3]

        # Center the X, Y, Z coordinates by subtracting the mean
        X_centered = X - np.mean(X)
        Y_centered = Y - np.mean(Y)
        Z_centered = Z - np.mean(Z)

        # Apply scaling: divide X, Y by 15 and Z by 20
        X_scaled = X_centered / 15.0
        Y_scaled = Y_centered / 15.0
        Z_scaled = Z_centered / 20.0

        # Stack the processed coordinates and intensity back into a point cloud
        pc_processed = np.stack([X_scaled, Y_scaled, Z_scaled, intensity], axis=1)

        processed_point_clouds.append(pc_processed)

    return processed_point_clouds

# Function to pad point clouds to have the same number of points
def pad_point_clouds(point_clouds, max_num_points):
    padded_point_clouds = []
    masks = []

    for pc in point_clouds:
        num_points = pc.shape[0]
        if num_points < max_num_points:
            # Pad with zeros
            pad_size = max_num_points - num_points
            padded_pc = np.pad(pc, ((0, pad_size), (0, 0)), 'constant', constant_values=0)  # Pad to the max_num_points
            mask = np.pad(np.ones(num_points), (0, pad_size), 'constant', constant_values=0)  # Create a mask
        else:
            padded_pc = pc[:max_num_points]  # Truncate if necessary
            mask = np.ones(max_num_points)  # Full mask if no padding is needed

        padded_point_clouds.append(padded_pc)
        masks.append(mask)

    return np.array(padded_point_clouds), np.array(masks)

# %%
import torch
import torch.optim as optim

# Loss function and optimizer
criterion = torch.nn.MSELoss()  # Mean Squared Error for regression

# Preprocess the point clouds data
processed_point_clouds = preprocess_point_clouds_with_centering(point_clouds)
test_processed_point_clouds = preprocess_point_clouds_with_centering(test_point_clouds)

# Model instantiation
input_dim = 4  # Example: XYZ + intensity
output_dim = 1  # Predicting AGB or wood volume
model = PointNetRegression(input_dim=input_dim, output_dim=output_dim)

# Now, initialize the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# Training loop
num_epochs = 40
batch_size = 8  # Adjust based on your GPU memory and dataset size

for epoch in range(num_epochs):
    model.train()

    total_loss = 0.0
    print(f"Starting epoch [{epoch+1}/{num_epochs}]...")

    for i in range(0, len(processed_point_clouds), batch_size):
        # Prepare batch data
        batch_point_clouds = processed_point_clouds[i:i+batch_size]
        batch_biomass_values = biomass_values[i:i+batch_size]

        # Find max number of points in the batch for padding
        max_num_points = max(pc.shape[0] for pc in batch_point_clouds)
        max_num_points = min(max_num_points, 20000)

        # Pad the point clouds and create masks
        padded_point_clouds, masks = pad_point_clouds(batch_point_clouds, max_num_points)

        # Convert to tensors
        point_clouds_tensor = torch.tensor(padded_point_clouds, dtype=torch.float32)  # Shape: (batch_size, max_num_points, input_dim)
        masks_tensor = torch.tensor(masks, dtype=torch.float32)  # Shape: (batch_size, max_num_points)
        biomass_values_tensor = torch.tensor(batch_biomass_values, dtype=torch.float32).unsqueeze(1)  # Shape: (batch_size, 1)

        optimizer.zero_grad()

        # print(point_clouds_tensor.shape)
        # print(masks_tensor.shape)
        # print(biomass_values_tensor.shape)

        # Forward pass with masking
        output = model(point_clouds_tensor, mask=masks_tensor)  # Pass the point clouds and mask through the model
        loss = criterion(output, biomass_values_tensor)  # Compute the loss

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # Print average loss at the end of each epoch
    avg_loss = total_loss / len(processed_point_clouds)
    print(f'Epoch [{epoch+1}/{num_epochs}], Avg Loss: {avg_loss:.4f}')
# Out:
# Starting epoch [1/40]...
# Epoch [1/40], Avg Loss: 69476.5076
# Starting epoch [2/40]...
# Epoch [2/40], Avg Loss: 59415.8904
# Starting epoch [3/40]...
# Epoch [3/40], Avg Loss: 43589.1878
# Starting epoch [4/40]...
# Epoch [4/40], Avg Loss: 29091.9964
# Starting epoch [5/40]...
# Epoch [5/40], Avg Loss: 21995.1658
# Starting epoch [6/40]...
# Epoch [6/40], Avg Loss: 21544.0019
# Starting epoch [7/40]...
# Epoch [7/40], Avg Loss: 20102.1949
# Starting epoch [8/40]...
# Epoch [8/40], Avg Loss: 19184.1392
# Starting epoch [9/40]...
# Epoch [9/40], Avg Loss: 19085.9826
# Starting epoch [10/40]...
# Epoch [10/40], Avg Loss: 19047.4332
# Starting epoch [11/40]...
# Epoch [11/40], Avg Loss: 18971.1852
# Starting epoch [12/40]...
# Epoch [12/40], Avg Loss: 18804.9645
# Starting epoch [13/40]...
# Epoch [13/40], Avg Loss: 18681.8880
# Starting epoch [14/40]...
# Epoch [14/40], Avg Loss: 18440.3343
# Starting epoch [15/40]...
# Epoch [15/40], Avg Loss: 18230.3769
# Starting epoch [16/40]...
# ...

# %%
save_path = '/content/drive/My Drive/TextFilesData/pointNet4_weights.pth'
torch.save(model.state_dict(), save_path)
print(f'Model weights saved to {save_path}')
# Out:
# Model weights saved to /content/drive/My Drive/TextFilesData/pointNet4_weights.pth

# %%
save_path = '/content/drive/My Drive/TextFilesData/pointNet_weights.pth'
torch.save(model.state_dict(), save_path)
print(f'Model weights saved to {save_path}')
# Out:
# Model weights saved to /content/drive/My Drive/TextFilesData/pointNet_weights.pth

# %%
# Load the saved model weights
save_path = '/content/drive/My Drive/TextFilesData/pointNet4_weights.pth'
model.load_state_dict(torch.load(save_path))
print(f'Model weights loaded from {save_path}')
# Out:
# Model weights loaded from /content/drive/My Drive/TextFilesData/pointNet4_weights.pth
# <ipython-input-21-a4e15dcdca51>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import torch
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

batch_size = 8
model.eval()

# Step 4: Disable gradient computation for faster inference
with torch.no_grad():
    total_predictions = []
    total_ground_truths = []

    # Step 5: Iterate over the test dataset
    for i in range(0, len(test_point_clouds), batch_size):
        # Prepare batch data
        batch_point_clouds = test_processed_point_clouds[i:i+batch_size]
        batch_biomass_values = test_biomass_values[i:i+batch_size]

        # Find max number of points in the batch for padding
        max_num_points = max(pc.shape[0] for pc in batch_point_clouds)
        max_num_points = min(max_num_points, 10000)

        # Pad the point clouds and create masks
        padded_point_clouds, masks = pad_point_clouds(batch_point_clouds, max_num_points)

        # Convert to tensors
        point_clouds_tensor = torch.tensor(padded_point_clouds, dtype=torch.float32)  # Shape: (batch_size, max_num_points, input_dim)
        masks_tensor = torch.tensor(masks, dtype=torch.float32)  # Shape: (batch_size, max_num_points)
        biomass_values_tensor = torch.tensor(batch_biomass_values, dtype=torch.float32).unsqueeze(1)  # Shape: (batch_size, 1)

        # Forward pass to get predictions
        output = model(point_clouds_tensor, mask=masks_tensor)

        # Append predictions and true values
        total_predictions.extend(output.numpy())
        total_ground_truths.extend(biomass_values_tensor.numpy())

# Step 6: Convert predictions and ground truths to numpy arrays
total_predictions = np.array(total_predictions)
total_ground_truths = np.array(total_ground_truths)

# Step 7: Calculate RMSE
rmse = np.sqrt(mean_squared_error(total_ground_truths, total_predictions))
mse=mean_squared_error(total_ground_truths, total_predictions)
r2=r2_score(total_ground_truths, total_predictions)
mae=mean_absolute_error(total_ground_truths, total_predictions)
print(f'MSE: {mse:.4f}')
print(f'RMSE: {rmse:.4f}')
print(f'MAE: {mae:.4f}')
print(f'R2: {r2:.4f}')
# Out:
# MSE: 141891.9062
# RMSE: 376.6854
# MAE: 333.0213
# R2: 0.0466

# %% [markdown]
# # Graph Knn

# %%
import numpy as np
from scipy.spatial import Delaunay

# Function to create a 3D graph from the point cloud using Delaunay triangulation
from sklearn.neighbors import NearestNeighbors

def create_knn_graph(points, k=6):
    # Create K-NN graph with k neighbors
    nbrs = NearestNeighbors(n_neighbors=k, algorithm='ball_tree').fit(points)
    distances, indices = nbrs.kneighbors(points)

    edges = set()
    for i in range(points.shape[0]):
        for j in indices[i]:
            edges.add((i, j))  # Add edge (i, j)
    return edges


# List to hold graphs for each point cloud
graphs = []
test_graphs=[]


for point_cloud in point_clouds:
    # Skip the header row if necessary (i.e., ['//X', 'Y', 'Z', 'intensity'])
    if isinstance(point_cloud[0][0], str):
        point_cloud = point_cloud[2:]  # Remove the header row

    # Convert point cloud to NumPy array for processing
    point_cloud_array = np.array(point_cloud, dtype=float)  # Ensure it is float

    # Create graph for current point cloud in 3D, handling NaN values
    try:
        edges = create_knn_graph(point_cloud_array, k=6)  # Using K=6 nearest neighbors
        graphs.append((point_cloud_array, edges))
  # Store points and their edges
    except ValueError as e:
        print(f"Skipping point cloud due to error: {e}")

# Now, 'graphs' contains a list of (point_cloud, edges) tuples, considering 3D space and NaN handling.


for point_cloud in test_point_clouds:
    # Skip the header row if necessary (i.e., ['//X', 'Y', 'Z', 'intensity'])
    if isinstance(point_cloud[0][0], str):
        point_cloud = point_cloud[2:]  # Remove the header row

    # Convert point cloud to NumPy array for processing
    test_point_cloud_array = np.array(point_cloud, dtype=float)  # Ensure it is float

    # Create graph for current point cloud in 3D, handling NaN values
    try:
        test_edges = create_knn_graph(test_point_cloud_array, k=6)  # Using K=6 nearest neighbors
        test_graphs.append((test_point_cloud_array, test_edges))
  # Store points and their edges
    except ValueError as e:
        print(f"Skipping point cloud due to error: {e}")

# %%
graphs[0][0].shape
# Out:
# (38783, 4)

# %%
edges
# Out:
# {(7778, 7062),
#  (1126, 1126),
#  (3008, 3200),
#  (16185, 16398),
#  (530, 314),
#  (3104, 2908),
#  (13358, 13358),
#  (18954, 19433),
#  (10260, 10040),
#  (14747, 14745),
#  (17116, 16907),
#  (52, 689),
#  (5571, 5578),
#  (17517, 18005),
#  (18332, 17400),
#  (5029, 5029),
#  (3790, 3586),
#  (700, 910),
#  (17459, 17246),
#  (2749, 2158),
#  (9522, 9522),
#  (3652, 3652),
#  (12841, 13024),
#  (17261, 17261),
#  (17951, 17708),
#  (18909, 18909),
#  (11903, 12475),
#  (19687, 19957),
#  (3412, 4165),
#  (20091, 19818),
#  (7543, 7545),
#  (21329, 21790),
#  (15644, 15643),
#  (10104, 9877),
#  (19962, 21101),
#  (14802, 14802),
#  (13425, 13425),
#  (21766, 21764),
#  (8002, 8244),
#  (2090, 2872),
#  (19594, 20116),
#  (12048, 12048),
#  (13364, 13149),
#  (11019, 11381),
#  (14971, 15550),
#  (16184, 15772),
#  (20826, 20388),
#  (2433, 3211),
#  (3173, 3775),
#  (11206, 11207),
#  (18456, 18001),
#  (15746, 15546),
#  (10651, 10396),
#  (7998, 8475),
#  (7941, 7941),
# ...

# %% [markdown]
# # Learning Rate 0.001 epoch 50

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data

# Assuming point_cloud_array is Nx4 (x, y, z, intensity) and edges is a list of edge pairs
def create_graph_data(point_cloud_array, edges):
    # Convert to torch tensors
    x = torch.tensor(point_cloud_array, dtype=torch.float)  # Node features: x, y, z, intensity
    edge_index = torch.tensor(list(edges), dtype=torch.long).t().contiguous()  # Edge list

    # Create a PyTorch Geometric data object
    data = Data(x=x, edge_index=edge_index)
    return data

# Create a graph for each point cloud
graph_data_list = [create_graph_data(pc, edge_list) for pc, edge_list in graphs]

# Define a simple GCN model
class GCN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return x.mean(dim=0)  # Return a global prediction for the whole graph (biomass)

# Initialize the model, loss function, and optimizer
input_dim = 4  # x, y, z, intensity
hidden_dim = 64
output_dim = 1  # Predicting a single biomass value
model = GCN(input_dim, hidden_dim, output_dim)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Example training loop
def train(model, data_list, biomass_values, epochs=50):
    model.train()
    for epoch in range(epochs):
        epoch_loss = 0
        for i, data in enumerate(data_list):
            optimizer.zero_grad()
            output = model(data)
            loss = F.mse_loss(output, torch.tensor([biomass_values[i]], dtype=torch.float))
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        print(f'Epoch {epoch+1}, Loss: {epoch_loss / len(data_list)}')

# Train the model
train(model, graph_data_list, biomass_values)
# Out:
# Epoch 1, Loss: 1039194.621174768
# Epoch 2, Loss: 153214.50604764154
# Epoch 3, Loss: 150222.66588370004
# Epoch 4, Loss: 111073.01631940054
# Epoch 5, Loss: 107245.86173012678
# Epoch 6, Loss: 107271.21378553148
# Epoch 7, Loss: 106284.17191664378
# Epoch 8, Loss: 102527.05041589573
# Epoch 9, Loss: 96356.00941315702
# Epoch 10, Loss: 88736.30580702037
# Epoch 11, Loss: 80631.83592943584
# Epoch 12, Loss: 73258.10737539857
# Epoch 13, Loss: 67755.43583519611
# Epoch 14, Loss: 64391.029857308255
# Epoch 15, Loss: 62501.36597120528
# Epoch 16, Loss: 61214.2065763006
# Epoch 17, Loss: 59885.77406501377
# Epoch 18, Loss: 58262.43399160983
# Epoch 19, Loss: 56412.429810403606
# Epoch 20, Loss: 54524.76300175751
# Epoch 21, Loss: 52784.07644201377
# Epoch 22, Loss: 51328.67087781028
# Epoch 23, Loss: 50224.01907505475
# Epoch 24, Loss: 49454.447527272154
# Epoch 25, Loss: 48951.75760402209
# Epoch 26, Loss: 48632.297699804105
# Epoch 27, Loss: 48426.364305600524
# ...

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to evaluate the model
def evaluate_model(model, data_list, biomass_values):
    model.eval()  # Set the model to evaluation mode
    predictions = []

    with torch.no_grad():  # Disable gradient calculation
        for data in data_list:
            output = model(data)
            predictions.append(output.item())  # Store predictions as scalars

    # Calculate metrics
    mse = mean_squared_error(biomass_values, predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(biomass_values, predictions)
    r2 = r2_score(biomass_values, predictions)

    print(f'Mean Squared Error (MSE): {mse}')
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print(f'R² Score: {r2}')

# Call the evaluation function
evaluate_model(model, graph_data_list, biomass_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf51118adbae> in <cell line: 26>()
#      24
#      25 # Call the evaluation function
# ---> 26 evaluate_model(model, graph_data_list, biomass_values)
#
# NameError: name 'model' is not defined

# %% [markdown]
# testing the test set

# %%
# Step 1: Load the test data
test_list_path = '/content/sample_data/TextFilesData/test_list.txt'
df_test = pd.read_csv(test_list_path, delim_whitespace=True, header=None)
df_test[0]=df_test[0]+df_test[1]
df_test[0] = df_test[0].str.replace('.pcd', '.txt')
df_test = df_test.drop(columns=[1])
# Base directory for the test data
base_dir = '/content/sample_data/TextFilesData'

# Load point clouds and biomass values from the test set
test_point_clouds = []
test_biomass_values = []

for _, row in df_test.iterrows():
    # Construct the full file path for the test set
    full_path = base_dir + row[0]  # row[0] contains the relative file path
    test_point_cloud = load_point_cloud(full_path)  # Load point cloud data

    test_point_clouds.append(test_point_cloud)
    test_biomass_values.append(row[2])  # Assuming biomass value is in the second column

# Convert to NumPy arrays
test_point_clouds = np.array(test_point_clouds, dtype=object)  # Use dtype=object for an array of arrays
test_biomass_values = np.array(test_biomass_values)

# Step 2: Create graphs for the test set
test_graphs = []

for point_cloud in test_point_clouds:
    # Skip the header row if necessary
    if isinstance(point_cloud[0][0], str):
        point_cloud = point_cloud[2:]  # Remove the header row

    # Convert point cloud to NumPy array for processing
    point_cloud_array = np.array(point_cloud, dtype=float)  # Ensure it is float

    # Create graph for current point cloud in 3D
    try:
        edges = create_knn_graph(point_cloud_array, k=6)  # Using K=6 nearest neighbors
        test_graphs.append((point_cloud_array, edges))
    except ValueError as e:
        print(f"Skipping point cloud due to error: {e}")

# Create graph data for the test set
test_graph_data_list = [create_graph_data(pc, edge_list) for pc, edge_list in test_graphs]

# Step 3: Make predictions on the test set
def predict(model, data_list):
    model.eval()  # Set the model to evaluation mode
    predictions = []

    with torch.no_grad():  # Disable gradient calculation
        for data in data_list:
            output = model(data)
            predictions.append(output.item())  # Store predictions as scalars

    return predictions

# Get predictions for the test set
test_predictions = predict(model, test_graph_data_list)

# Step 4: Evaluate the predictions
evaluate_model(model, test_graph_data_list, test_biomass_values)
# Out:
# <ipython-input-22-c2081eebd5d3>:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_test = pd.read_csv(test_list_path, delim_whitespace=True, header=None)

# %% [markdown]
# # Learning rate 0.01

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data

# Assuming point_cloud_array is Nx4 (x, y, z, intensity) and edges is a list of edge pairs
def create_graph_data(point_cloud_array, edges):
    # Convert to torch tensors
    x = torch.tensor(point_cloud_array, dtype=torch.float)  # Node features: x, y, z, intensity
    edge_index = torch.tensor(list(edges), dtype=torch.long).t().contiguous()  # Edge list

    # Create a PyTorch Geometric data object
    data = Data(x=x, edge_index=edge_index)
    return data

# %%
# Create a graph for each point cloud
# graph_data_list = [create_graph_data(pc, edge_list) for pc, edge_list in graphs]
test_graph_data_list = [create_graph_data(pc, edge_list) for pc, edge_list in test_graphs]

# Define a simple GCN model
class GCN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return x.mean(dim=0)  # Return a global prediction for the whole graph (biomass)

# %%
# Initialize the model, loss function, and optimizer
input_dim = 4  # x, y, z, intensity
hidden_dim = 64
output_dim = 1  # Predicting a single biomass value
model2 = GCN(input_dim, hidden_dim, output_dim)
optimizer = torch.optim.Adam(model2.parameters(), lr=0.01)

# %%
# Example training loop
def train(model2, data_list, biomass_values, epochs=50):
    model2.train()
    for epoch in range(epochs):
        epoch_loss = 0
        for i, data in enumerate(data_list):
            optimizer.zero_grad()
            output = model2(data)
            loss = F.mse_loss(output, torch.tensor([biomass_values[i]], dtype=torch.float))
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        print(f'Epoch {epoch+1}, Loss: {epoch_loss / len(data_list)}')

# Train the model2
train(model2, graph_data_list, biomass_values)
# Out:
# Epoch 1, Loss: 3186364.8116518655
# Epoch 2, Loss: 841599.8765953849
# Epoch 3, Loss: 1601352.5885367207
# Epoch 4, Loss: 479000.6280106189
# Epoch 5, Loss: 412844.37238759623
# Epoch 6, Loss: 366407.0686195465
# Epoch 7, Loss: 301592.1777726178
# Epoch 8, Loss: 253298.27984928808
# Epoch 9, Loss: 215109.32056844124
# Epoch 10, Loss: 184919.62807285084
# Epoch 11, Loss: 160896.8354586807
# Epoch 12, Loss: 141405.48952389698
# Epoch 13, Loss: 125483.87365455253
# Epoch 14, Loss: 111955.47393726952
# Epoch 15, Loss: 100585.45295555232
# Epoch 16, Loss: 90797.39696361855
# Epoch 17, Loss: 82297.96958251912
# Epoch 18, Loss: 74990.84629061996
# Epoch 19, Loss: 68770.11210044824
# Epoch 20, Loss: 63551.06837877942
# Epoch 21, Loss: 59183.11843954348
# Epoch 22, Loss: 55382.73850527172
# Epoch 23, Loss: 52997.63333956868
# Epoch 24, Loss: 51330.8429874994
# Epoch 25, Loss: 47968.672530148404
# Epoch 26, Loss: 47542.6876402357
# Epoch 27, Loss: 49923.02125586562
# ...

# %%
model_save_path = '/content/drive/My Drive/TextFilesData/model2_weights.pth'
torch.save(model2.state_dict(), model_save_path)
print(f'Model weights saved to {model_save_path}')
# Out:
# Model weights saved to /content/drive/My Drive/TextFilesData/model2_weights.pth

# %%
# Load the saved model weights
save_path = '/content/drive/My Drive/TextFilesData/model2_weights.pth'
model2.load_state_dict(torch.load(save_path))
print(f'Model weights loaded from {save_path}')
# Out:
# Model weights loaded from /content/drive/My Drive/TextFilesData/model2_weights.pth
# <ipython-input-15-0fc4794845d6>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to evaluate the model2
def evaluate_model2(model2, data_list, biomass_values):
    model2.eval()  # Set the model2 to evaluation mode
    predictions = []

    with torch.no_grad():  # Disable gradient calculation
        for data in data_list:
            output = model2(data)
            predictions.append(output.item())  # Store predictions as scalars

    # Calculate metrics
    mse = mean_squared_error(biomass_values, predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(biomass_values, predictions)
    r2 = r2_score(biomass_values, predictions)

    print(f'Mean Squared Error (MSE): {mse}')
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print(f'R² Score: {r2}')

# Call the evaluation function
evaluate_model2(model2, graph_data_list, biomass_values)
# Out:
# Mean Squared Error (MSE): 58733.00158595787
# Root Mean Squared Error (RMSE): 242.3489252832739
# Mean Absolute Error (MAE): 213.0535981720569
# R² Score: 0.5882522090800967

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to evaluate the model2
def evaluate_model2(model2, data_list, biomass_values):
    model2.eval()  # Set the model2 to evaluation mode
    test_predictions = []

    with torch.no_grad():  # Disable gradient calculation
        for data in data_list:
            output = model2(data)
            test_predictions.append(output.item())  # Store predictions as scalars

    # Calculate metrics
    mse = mean_squared_error(biomass_values, test_predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(biomass_values, test_predictions)
    r2 = r2_score(biomass_values, test_predictions)

    print(f'Mean Squared Error (MSE): {mse}')
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print(f'R² Score: {r2}')

# Call the evaluation function
evaluate_model2(model2, test_graph_data_list, test_biomass_values)
# Out:
# Mean Squared Error (MSE): 53595.482153103185
# Root Mean Squared Error (RMSE): 231.50698078698014
# Mean Absolute Error (MAE): 202.25197342218138
# R² Score: 0.6398965342457836

# %% [markdown]
# # Learning rate 0.001 epoch 70

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data

# Assuming point_cloud_array is Nx4 (x, y, z, intensity) and edges is a list of edge pairs
def create_graph_data(point_cloud_array, edges):
    # Convert to torch tensors
    x = torch.tensor(point_cloud_array, dtype=torch.float)  # Node features: x, y, z, intensity
    edge_index = torch.tensor(list(edges), dtype=torch.long).t().contiguous()  # Edge list

    # Create a PyTorch Geometric data object
    data = Data(x=x, edge_index=edge_index)
    return data

# Create a graph for each point cloud
graph_data_list = [create_graph_data(pc, edge_list) for pc, edge_list in graphs]

# Define a simple GCN model3
class GCN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return x.mean(dim=0)  # Return a global prediction for the whole graph (biomass)

# Initialize the model3, loss function, and optimizer
input_dim = 4  # x, y, z, intensity
hidden_dim = 64
output_dim = 1  # Predicting a single biomass value
model3 = GCN(input_dim, hidden_dim, output_dim)
optimizer = torch.optim.Adam(model3.parameters(), lr=0.001)

# Example training loop
def train(model3, data_list, biomass_values, epochs=70):
    model3.train()
    for epoch in range(epochs):
        epoch_loss = 0
        for i, data in enumerate(data_list):
            optimizer.zero_grad()
            output = model3(data)
            loss = F.mse_loss(output, torch.tensor([biomass_values[i]], dtype=torch.float))
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        print(f'Epoch {epoch+1}, Loss: {epoch_loss / len(data_list)}')

# Train the model3
train(model3, graph_data_list, biomass_values)
# Out:
# Epoch 1, Loss: 60893129.794742115
# Epoch 2, Loss: 101830.03386184222
# Epoch 3, Loss: 100122.73806680417
# Epoch 4, Loss: 100146.30099145572
# Epoch 5, Loss: 98666.92310088084
# Epoch 6, Loss: 95422.99958166305
# Epoch 7, Loss: 91371.61226087458
# Epoch 8, Loss: 87933.64431777538
# Epoch 9, Loss: 85582.8040160268
# Epoch 10, Loss: 83899.61147059033
# Epoch 11, Loss: 82550.25582950548
# Epoch 12, Loss: 81856.08774145562
# Epoch 13, Loss: 82339.1760461516
# Epoch 14, Loss: 84390.56157294441
# Epoch 15, Loss: 89422.46679384568
# Epoch 16, Loss: 96985.16479993341
# Epoch 17, Loss: 95251.06353120944
# Epoch 18, Loss: 83978.19883837653
# Epoch 19, Loss: 66441.95600288289
# Epoch 20, Loss: 56135.73827434054
# Epoch 21, Loss: 53739.42635908065
# Epoch 22, Loss: 54500.4481979889
# Epoch 23, Loss: 56239.010375265985
# Epoch 24, Loss: 55918.521181883494
# Epoch 25, Loss: 53341.830935169666
# Epoch 26, Loss: 50828.7910987054
# Epoch 27, Loss: 50315.80419545277
# ...

# %%
model_save_path = '/content/drive/My Drive/TextFilesData/model3_weights.pth'
torch.save(model3.state_dict(), model_save_path)
print(f'Model weights saved to {model_save_path}')
# Out:
# Model weights saved to /content/drive/My Drive/TextFilesData/model3_weights.pth

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to evaluate the model3
def evaluate_model3(model3, data_list, biomass_values):
    model3.eval()  # Set the model3 to evaluation mode
    predictions = []

    with torch.no_grad():  # Disable gradient calculation
        for data in data_list:
            output = model3(data)
            predictions.append(output.item())  # Store predictions as scalars

    # Calculate metrics
    mse = mean_squared_error(biomass_values, predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(biomass_values, predictions)
    r2 = r2_score(biomass_values, predictions)

    print(f'Mean Squared Error (MSE): {mse}')
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print(f'R² Score: {r2}')

# Call the evaluation function
evaluate_model3(model3, graph_data_list, biomass_values)
# Out:
# Mean Squared Error (MSE): 44446.34228794267
# Root Mean Squared Error (RMSE): 210.82301176091445
# Mean Absolute Error (MAE): 162.7389354573979
# R² Score: 0.6884088543517299

# %% [markdown]
# # Learning Rate 0.01 Epoch 70

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data

# Assuming point_cloud_array is Nx4 (x, y, z, intensity) and edges is a list of edge pairs
def create_graph_data(point_cloud_array, edges):
    # Convert to torch tensors
    x = torch.tensor(point_cloud_array, dtype=torch.float)  # Node features: x, y, z, intensity
    edge_index = torch.tensor(list(edges), dtype=torch.long).t().contiguous()  # Edge list

    # Create a PyTorch Geometric data object
    data = Data(x=x, edge_index=edge_index)
    return data

# Create a graph for each point cloud
graph_data_list = [create_graph_data(pc, edge_list) for pc, edge_list in graphs]

# Define a simple GCN model
class GCN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return x.mean(dim=0)  # Return a global prediction for the whole graph (biomass)

# Initialize the model, loss function, and optimizer
input_dim = 4  # x, y, z, intensity
hidden_dim = 64
output_dim = 1  # Predicting a single biomass value
model4 = GCN(input_dim, hidden_dim, output_dim)
optimizer = torch.optim.Adam(model4.parameters(), lr=0.01)

# Example training loop
def train(model4, data_list, biomass_values, epochs=70):
    model4.train()
    for epoch in range(epochs):
        epoch_loss = 0
        for i, data in enumerate(data_list):
            optimizer.zero_grad()
            output = model4(data)
            loss = F.mse_loss(output, torch.tensor([biomass_values[i]], dtype=torch.float))
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        print(f'Epoch {epoch+1}, Loss: {epoch_loss / len(data_list)}')

# Train the model4
train(model4, graph_data_list, biomass_values)
# Out:
# Epoch 1, Loss: 17632882.52067599
# Epoch 2, Loss: 212744.02764589645
# Epoch 3, Loss: 194154.53415882355
# Epoch 4, Loss: 190363.36144432783
# Epoch 5, Loss: 161541.96545861807
# Epoch 6, Loss: 820870.5423588677
# Epoch 7, Loss: 797976.3491806868
# Epoch 8, Loss: 682621.9510300299
# Epoch 9, Loss: 536257.2736156859
# Epoch 10, Loss: 466335.7700737598
# Epoch 11, Loss: 400948.0049905216
# Epoch 12, Loss: 349294.1802150724
# Epoch 13, Loss: 306342.0390688859
# Epoch 14, Loss: 270252.33224816417
# Epoch 15, Loss: 239782.3239595563
# Epoch 16, Loss: 213718.5025035634
# Epoch 17, Loss: 191315.26416516537
# Epoch 18, Loss: 171880.76312208877
# Epoch 19, Loss: 154857.17022954675
# Epoch 20, Loss: 139905.79662015187
# Epoch 21, Loss: 126696.91575736129
# Epoch 22, Loss: 114818.04992989202
# Epoch 23, Loss: 104281.10823702111
# Epoch 24, Loss: 94777.19841249521
# Epoch 25, Loss: 86220.68873251887
# Epoch 26, Loss: 78167.69601866734
# Epoch 27, Loss: 71213.75167759639
# ...

# %%
model_save_path = '/content/drive/My Drive/TextFilesData/model4_weights.pth'
torch.save(model4.state_dict(), model_save_path)
print(f'Model weights saved to {model_save_path}')
# Out:
# Model weights saved to /content/drive/My Drive/TextFilesData/model4_weights.pth

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to evaluate the model4
def evaluate_model4(model4, data_list, biomass_values):
    model4.eval()  # Set the model4 to evaluation mode
    predictions = []

    with torch.no_grad():  # Disable gradient calculation
        for data in data_list:
            output = model4(data)
            predictions.append(output.item())  # Store predictions as scalars

    # Calculate metrics
    mse = mean_squared_error(biomass_values, predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(biomass_values, predictions)
    r2 = r2_score(biomass_values, predictions)

    print(f'Mean Squared Error (MSE): {mse}')
    print(f'Root Mean Squared Error (RMSE): {rmse}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print(f'R² Score: {r2}')

# Call the evaluation function
evaluate_model4(model4, graph_data_list, biomass_values)
# Out:
# Mean Squared Error (MSE): 57882.05444844644
# Root Mean Squared Error (RMSE): 240.58689583692302
# Mean Absolute Error (MAE): 207.72067936915974
# R² Score: 0.5942177751945266
